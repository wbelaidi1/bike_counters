# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import datetime

_target_column_name = "log_bike_count"

# %%
from jours_feries_france import JoursFeries

# %%
X["date"]
# Out:
# 400125   2020-09-01 01:00:00
# 408305   2020-09-01 01:00:00
# 87516    2020-09-01 01:00:00
# 98518    2020-09-01 01:00:00
# 875137   2020-09-01 01:00:00
#                  ...
# 792857   2021-09-09 23:00:00
# 805182   2021-09-09 23:00:00
# 815218   2021-09-09 23:00:00
# 125979   2021-09-09 23:00:00
# 135985   2021-09-09 23:00:00
# Name: date, Length: 496827, dtype: datetime64[us]

# %%
for x in X["date"]:
    #JoursFeries.is_bank_holiday(datetime.date(x.dt.year, x.dt.month, x.dt.day), zone="Métropole")
    print(x.year)
# Out:
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# ...

# %%
def _encode_dates(X):
    X = X.copy()  # modify a copy of X
    # Encode the date information from the DateOfDeparture columns
    X["year"] = X["date"].dt.year
    X["month"] = X["date"].dt.month
    X["day"] = X["date"].dt.day
    X["weekday"] = X["date"].dt.weekday
    X["hour"] = X["date"].dt.hour
    x["ferie"] = JoursFeriesX["date"]

    # Finally we can drop the original columns from the dataframe
    return X.drop(columns=["date"])

# %%
def train_test_split_temporal(X, y, delta_threshold="30 days"):
    
    cutoff_date = X["date"].max() - pd.Timedelta(delta_threshold)
    mask = (X["date"] <= cutoff_date)
    X_train, X_valid = X.loc[mask], X.loc[~mask]
    y_train, y_valid = y[mask], y[~mask]

    return X_train, y_train, X_valid, y_valid

# %%
def get_train_data(path="data/train.parquet"):
    data = pd.read_parquet(path)
    # Sort by date first, so that time based cross-validation would produce correct results
    data = data.sort_values(["date", "counter_name"])
    y_array = data[_target_column_name].values
    X_df = data.drop([_target_column_name, "bike_count"], axis=1)
    return X_df, y_array

# %%
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder

# %%
X, y = get_train_data()
X_train, y_train, X_valid, y_valid = train_test_split_temporal(X, y)
date_encoder = FunctionTransformer(_encode_dates)
date_cols = _encode_dates(X_train[["date"]]).columns.tolist()

# %%
data_a = data[["counter_name", "log_bike_count", "date"]]

# %%
data_encoded = _encode_dates(data_a)

# %%
data_a
# Out:
#                       counter_name  log_bike_count                date
# 48321     28 boulevard Diderot E-O        0.000000 2020-09-01 02:00:00
# 48324     28 boulevard Diderot E-O        0.693147 2020-09-01 03:00:00
# 48327     28 boulevard Diderot E-O        0.000000 2020-09-01 04:00:00
# 48330     28 boulevard Diderot E-O        1.609438 2020-09-01 15:00:00
# 48333     28 boulevard Diderot E-O        2.302585 2020-09-01 18:00:00
# ...                            ...             ...                 ...
# 929175  254 rue de Vaugirard SO-NE        6.100319 2021-09-09 06:00:00
# 929178  254 rue de Vaugirard SO-NE        4.983607 2021-09-09 10:00:00
# 929181  254 rue de Vaugirard SO-NE        5.389072 2021-09-09 15:00:00
# 929184  254 rue de Vaugirard SO-NE        3.091042 2021-09-09 22:00:00
# 929187  254 rue de Vaugirard SO-NE        2.772589 2021-09-09 23:00:00
#
# [496827 rows x 3 columns]

# %%
mask = (
    (data_a["counter_name"] == "Totem 73 boulevard de Sébastopol S-N")
    & (data_a["date"] > pd.to_datetime("2021/07/11"))
    & (data_a["date"] < pd.to_datetime("2021/07/17"))
)

# %%
data_plot = data_a[mask]
data_plot
# Out:
#                                 counter_name  log_bike_count  \
# 830879  Totem 73 boulevard de Sébastopol S-N        3.891820
# 830882  Totem 73 boulevard de Sébastopol S-N        3.713572
# 830885  Totem 73 boulevard de Sébastopol S-N        3.178054
# 830888  Totem 73 boulevard de Sébastopol S-N        3.332205
# 830891  Totem 73 boulevard de Sébastopol S-N        3.970292
# ...                                      ...             ...
# 833797  Totem 73 boulevard de Sébastopol S-N        5.733341
# 833800  Totem 73 boulevard de Sébastopol S-N        5.631212
# 833803  Totem 73 boulevard de Sébastopol S-N        6.413459
# 833806  Totem 73 boulevard de Sébastopol S-N        6.436150
# 833809  Totem 73 boulevard de Sébastopol S-N        5.866468
#
#                       date
# 830879 2021-07-11 01:00:00
# 830882 2021-07-11 02:00:00
# 830885 2021-07-11 03:00:00
# 830888 2021-07-11 04:00:00
# 830891 2021-07-11 06:00:00
# ...                    ...
# 833797 2021-07-16 10:00:00
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 4))

data_plot.plot.scatter(x="date", y="log_bike_count", ax=ax)
# Out:
# <Axes: xlabel='date', ylabel='log_bike_count'>
